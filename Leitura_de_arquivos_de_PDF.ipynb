# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardosiebra/Projeto-PDF/blob/main/Leitura_de_arquivos_de_PDF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install tabula-py pandas

# %%
import pandas as pd
import tabula
from tabula import read_pdf

# %%
# Lê todas as tabelas do PDF em uma lista de DataFrames
tabelas = tabula.read_pdf("CONTABIL.pdf", pages="all")
print(tabelas)

# %%
table = tabelas[0]
print(table)
# Out:
#                 Conta                           Descrição Saldo Anterior  \
# 0                   1                                 ATIVO 622.235,56 D
# 1                 1.1                      ATIVO CIRCULANTE 601.290,53 D
# 2               1.1.1                       DISPONIBILIDADES 89.833,28 D
# 3            1.1.1.01                             TESOURARIA 42.840,40 D
# 4         1.1.1.01.01                            CAIXA GERAL 42.840,40 D
# 5      1.1.1.01.01.01                       Caixa Tesouraria 42.840,40 D
# 6            1.1.1.02                 BANCOS CONTA MOVIMENTO 46.992,88 D
# 7         1.1.1.02.01                       CONTAS CORRENTES 46.992,88 D
# 8      1.1.1.02.01.01  Banco Inter Cta. 231294972 Ag. 0001-09 46.992,...
# 9               1.1.3                              ESTOQUES 218.595,41 D
# 10           1.1.3.01                       ESTOQUES GERAIS 218.595,41 D
# 11        1.1.3.01.01              MERCADORIAS PARA REVENDA 218.595,41 D
# ...

# %%
df = pd.DataFrame(table)
display(df)
# Out:
#                 Conta                           Descrição Saldo Anterior  \
# 0                   1                                 ATIVO 622.235,56 D
# 1                 1.1                      ATIVO CIRCULANTE 601.290,53 D
# 2               1.1.1                       DISPONIBILIDADES 89.833,28 D
# 3            1.1.1.01                             TESOURARIA 42.840,40 D
# 4         1.1.1.01.01                            CAIXA GERAL 42.840,40 D
# 5      1.1.1.01.01.01                       Caixa Tesouraria 42.840,40 D
# 6            1.1.1.02                 BANCOS CONTA MOVIMENTO 46.992,88 D
# 7         1.1.1.02.01                       CONTAS CORRENTES 46.992,88 D
# 8      1.1.1.02.01.01  Banco Inter Cta. 231294972 Ag. 0001-09 46.992,...
# 9               1.1.3                              ESTOQUES 218.595,41 D
# 10           1.1.3.01                       ESTOQUES GERAIS 218.595,41 D
# 11        1.1.3.01.01              MERCADORIAS PARA REVENDA 218.595,41 D
# ...
